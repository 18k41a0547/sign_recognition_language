# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense , Dropout
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
sz = 128
# Step 1 - Building the CNN

# Initializing the CNN
classifier = Sequential()

# First convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), input_shape=(sz, sz, 1), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
# Second convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Flattening the layers
classifier.add(Flatten())

# Adding a fully connected layer
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=96, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dense(units=29, activation='softmax')) # softmax for more than 2

# Compiling the CNN
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # categorical_crossentropy for more than 2


# Step 2 - Preparing the train/test data and training the model
classifier.summary()
# Code copied from - https://keras.io/preprocessing/image/
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('data2/train',
                                                 target_size=(sz, sz),
                                                 batch_size=10,
                                                 color_mode='grayscale',
                                                 class_mode='categorical')

test_set = test_datagen.flow_from_directory('data2/test',
                                            target_size=(sz , sz),
                                            batch_size=10,
                                            color_mode='grayscale',
                                            class_mode='categorical')
classifier.fit_generator(
        training_set,
        steps_per_epoch=len(training_set), #(14720) No of images in training set
        epochs=10,
        validation_data=test_set,
        validation_steps= len(test_set)) #(8058) No of images in test set
                                            


# Saving the model
model_json = classifier.to_json()
with open("model-bw.json", "w") as json_file:
    json_file.write(model_json)
print('Model Saved')
classifier.save_weights('model-bw.h5')
print('Weights saved')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               3686528
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 96)                12384
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                6208
# _________________________________________________________________
# dense_15 (Dense)             (None, 29)                1885
# =================================================================
# Total params: 3,716,573
# Trainable params: 3,716,573
# Non-trainable params: 0
# _________________________________________________________________
# Found 8058 images belonging to 29 classes.
# Found 14720 images belonging to 29 classes.
# Epoch 1/10
# 806/806 [==============================] - 144s 179ms/step - loss: 1.6247 - accuracy: 0.5073 - val_loss: 6.4324 - val_accuracy: 0.1060
# Epoch 2/10
# 806/806 [==============================] - 148s 184ms/step - loss: 0.5671 - accuracy: 0.8245 - val_loss: 6.7982 - val_accuracy: 0.1303
# Epoch 3/10
# 806/806 [==============================] - 143s 178ms/step - loss: 0.3615 - accuracy: 0.8860 - val_loss: 7.1208 - val_accuracy: 0.1746
# Epoch 4/10
# 806/806 [==============================] - 145s 179ms/step - loss: 0.2506 - accuracy: 0.9212 - val_loss: 7.2907 - val_accuracy: 0.1774
# Epoch 5/10
# 806/806 [==============================] - 145s 179ms/step - loss: 0.1982 - accuracy: 0.9352 - val_loss: 8.1439 - val_accuracy: 0.1774
# Epoch 6/10
# 806/806 [==============================] - 156s 193ms/step - loss: 0.1703 - accuracy: 0.9465 - val_loss: 7.7635 - val_accuracy: 0.2111
# Epoch 7/10
# 806/806 [==============================] - 158s 196ms/step - loss: 0.1648 - accuracy: 0.9485 - val_loss: 7.8840 - val_accuracy: 0.1813
# Epoch 8/10
# 806/806 [==============================] - 150s 187ms/step - loss: 0.1286 - accuracy: 0.9617 - val_loss: 8.7128 - val_accuracy: 0.1792
# Epoch 9/10
# 806/806 [==============================] - 149s 185ms/step - loss: 0.1138 - accuracy: 0.9641 - val_loss: 9.4801 - val_accuracy: 0.2016
# Epoch 10/10
# 806/806 [==============================] - 156s 194ms/step - loss: 0.1302 - accuracy: 0.9645 - val_loss: 8.1660 - val_accuracy: 0.1897
# Model Saved
# Weights saved
